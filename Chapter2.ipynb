# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/MyDrive/Colab Notebooks/IS110_BPerformance_Bantillo/PythonEnvi_Bantillo
# Out:
# /content/drive/MyDrive/Colab Notebooks/IS110_BPerformance_Bantillo/PythonEnvi_Bantillo

# %% [markdown]
# ## EXERCISES

# %% [markdown]
# #### Exercise 1

# %%
name=input('Enter your name my friend: ')
print ('Hello', name)
# Out:
# Enter your name my friend: kurt
# Hello kurt

# %%
name = input("Name: ")
print("You are", name)

# %% [markdown]
# #### Exercise 2

# %%
hours = input("Hours: ")
rate = input("Rate: ")
pay= int(hours) * int(rate)
print ('Pay: ', pay)

# %% [markdown]
# #### Exercise 3

# %%
width = 17      # int
height = 12.0   # float

# %%
n=input('Enter a number:' )
square= int(n)**2
print ('The square of', n, 'is ', square)
# Out:
# Enter a number:2
# The square of 2 is  4

# %% [markdown]
# ## CHALLENGE

# %%
Cel = input('Please enter the temperature in Celsius: ')
Celsius = float(Cel)

Fah = (Celsius * 1.8) + 32

print(f"{Celsius} degrees Celsius is equal to {Fah} degrees Fahrenheit.")
# Out:
# Please enter the temperature in Celsius: 99
# 99.0 degrees Celsius is equal to 210.20000000000002 degrees Fahrenheit.
